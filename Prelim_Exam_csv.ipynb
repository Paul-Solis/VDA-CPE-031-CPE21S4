# %% [markdown]
# <a href="https://colab.research.google.com/github/Paul-Solis/VDA-CPE-031-CPE21S4/blob/main/Prelim_Exam_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 11

# %%
import pandas as pd


data = {'X': [78, 85, 96, 80, 86],
        'Y': [84, 94, 89, 83, 86],
        'Z': [86, 97, 96, 72, 83]}


df = pd.DataFrame(data)


df
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83

# %% [markdown]
# question 12

# %%
import pandas as pd
DataSet = {"col 1": [1,4,3,4,5],
           "col 2" : [4,5,6,7,8],
           "col 3" :[7,8,9,0,1]}


df = pd.DataFrame(DataSet)
print(df.drop(1))
# Out:
#    col 1  col 2  col 3
# 0      1      4      7
# 2      3      6      9
# 3      4      7      0
# 4      5      8      1

# %% [markdown]
# question 13

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c00cee1f-3fb2-4a91-ae1e-a0c4bdc1d0bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c00cee1f-3fb2-4a91-ae1e-a0c4bdc1d0bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('ComputerData.csv')

print(df)
# Out:
#    Computer ID   Brand        Model    Processor  RAM (GB)  Storage (GB)  \
# 0            1    Dell       XPS 13     Intel i7        16           512
# 1            2      HP  Pavilion 15  AMD Ryzen 5         8           256
# 2            3   Apple  MacBook Pro     Apple M1        16          1024
# 3            4  Lenovo  ThinkPad X1     Intel i9        32           512
# 4            5    Asus   ZenBook 14     Intel i5        16           512
#
#       Graphics Card  Price ($)
# 0     Intel Iris Xe       1200
# 1        AMD Radeon        800
# 2  Apple Integrated       2400
# 3   NVIDIA GTX 1650       1800
# 4      NVIDIA MX250       1000

# %%
from tabulate import tabulate
print (tabulate(df, headers='keys', tablefmt='psql', showindex=False))
# Out:
# +---------------+---------+-------------+-------------+------------+----------------+------------------+-------------+
# |   Computer ID | Brand   | Model       | Processor   |   RAM (GB) |   Storage (GB) | Graphics Card    |   Price ($) |
# |---------------+---------+-------------+-------------+------------+----------------+------------------+-------------|
# |             1 | Dell    | XPS 13      | Intel i7    |         16 |            512 | Intel Iris Xe    |        1200 |
# |             2 | HP      | Pavilion 15 | AMD Ryzen 5 |          8 |            256 | AMD Radeon       |         800 |
# |             3 | Apple   | MacBook Pro | Apple M1    |         16 |           1024 | Apple Integrated |        2400 |
# |             4 | Lenovo  | ThinkPad X1 | Intel i9    |         32 |            512 | NVIDIA GTX 1650  |        1800 |
# |             5 | Asus    | ZenBook 14  | Intel i5    |         16 |            512 | NVIDIA MX250     |        1000 |
# ...

# %%
df.to_csv('ComputerData.csv')
pd.read_csv('ComputerData.csv')
# Out:
#    Unnamed: 0  Computer ID   Brand        Model    Processor  RAM (GB)  \
# 0           0            1    Dell       XPS 13     Intel i7        16
# 1           1            2      HP  Pavilion 15  AMD Ryzen 5         8
# 2           2            3   Apple  MacBook Pro     Apple M1        16
# 3           3            4  Lenovo  ThinkPad X1     Intel i9        32
# 4           4            5    Asus   ZenBook 14     Intel i5        16
#
#    Storage (GB)     Graphics Card  Price ($)
# 0           512     Intel Iris Xe       1200
# 1           256        AMD Radeon        800
# 2          1024  Apple Integrated       2400
# 3           512   NVIDIA GTX 1650       1800
# 4           512      NVIDIA MX250       1000
