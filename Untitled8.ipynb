# %% [markdown]
# <a href="https://colab.research.google.com/github/Paul-Solis/VDA-CPE-031-CPE21S4/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from google.colab import files

# %% [markdown]
# 1

# %%
uploaded = files.upload()
data = pd.read_csv('Technological-Products-Sample-Data - Sheet1 (2).csv')
data
# Out:
#      <input type="file" id="files-cc7f6392-08d9-4d74-9822-a44e9e2c88b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc7f6392-08d9-4d74-9822-a44e9e2c88b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 3.a

# %%
data = pd.read_csv('Technological-Products-Sample-Data - Sheet1 (2).csv')


x = data['Date of Release']
y = data['Price (USD)']

plt.plot(x, y)
plt.title('Date of Release vs Price')
plt.xlabel("Date of Release")
plt.ylabel("Price (USD)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 3.b

# %%
data = pd.read_csv('Technological-Products-Sample-Data - Sheet1 (2).csv')


x = data['Date of Release']
y = data['Price (USD)']

plt.plot(x, y)
plt.title('Date of Release and Sale')
plt.xlabel("Date of Release")
plt.ylabel("Price (USD)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 3.b

# %%
data = pd.read_csv('Technological-Products-Sample-Data - Sheet1 (2).csv')

x = data['Date of Release']
y = data['Price (USD)']
plt.figure(figsize=(12, 6))
plt.plot(x, y, color='red', marker='o', linestyle=':',linewidth='3')


plt.title('Date of Release and Sale')
plt.xlabel("Date of Release")
plt.ylabel("Price (USD)")
plt.xticks(rotation=90)
plt.show()
