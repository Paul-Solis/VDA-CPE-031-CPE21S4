# %% [markdown]
# <a href="https://colab.research.google.com/github/Paul-Solis/VDA-CPE-031-CPE21S4/blob/main/EXERCISE_8_SOLIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import matplotlib
import matplotlib.pyplot as plt
print(matplotlib.__version__)
# Out:
# 3.7.1

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, marker='*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, 'o:b')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, 'o:b',ms=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, 'o:b',ms=10,mec='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints,'o:b', ms=10, mec='green', mfc='red')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, ms=10, mec='green', mfc='red', linestyle='dashed')
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.title("distance travelled everyday")
plt.xlabel("distance in km")
plt.ylabel("speed in km/s")
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.title("distance travelled everyday")
plt.xlabel("distance in km")
plt.ylabel("speed in km/s")
plt.grid(axis = 'y')
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)

plt.title("Distance Travelled Everyday", loc = "left")
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")
plt.grid(axis ='x', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])
plt.subplot(1,2,1)
plt.plot(xpoints, ypoints)

xpoints = np.array([1, 3, 6, 8])
ypoints = np.array([10, 20, 30, 40])
plt.subplot(1,2,2)
plt.plot(xpoints, ypoints)

plt.grid(axis = 'x', linestyle = '--', linewidth = 0.50)
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])
plt.scatter(xpoints, ypoints)

xpoints = np.array([1, 3, 6, 8])
ypoints = np.array([10, 20, 30, 40])
plt.scatter(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['Student1', 'Student2', 'Student3'])
y = np.array([90, 85, 86])
plt.bar(x,y)
plt.show()

# %%
g = np.array([35,25,25,15])
grader = ["Grade 1=35%", "Grade 2=25%", "Grade 3=25%", "Grade 4=15%"]
plt.pie(g, labels = grader)
plt.show()

# %% [markdown]
# PART **1**

# %%
import matplotlib.pyplot as plt

labels = ['A' , 'B' , 'C']
sizes = [40, 30, 30]

plt.pie(sizes, labels=labels)
plt.title("Pie Chart Example")
plt.show()

# %% [markdown]
# line plot

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.title("Line Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# scatter plot

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.scatter(x, y)
plt.title("Scatter Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# histogram

# %%
import matplotlib.pyplot as plt

data = [1, 2, 2, 3, 3, 3, 4, 4, 5]

plt.hist(data)
plt.title("Histogram Example")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# bar chart

# %%
import matplotlib.pyplot as plt

categories = ['A', 'B', 'C']
values = [5, 7, 3]

plt.bar(categories, values)
plt.title("Bar Chart Example")
plt.xlabel("Category")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# box plot

# %%
import matplotlib.pyplot as plt

data = [[1.5]*10 + [2]*10 + [3]*10 ]

plt.boxplot(data)
plt.title("Box Plot Example")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# PART 2

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-fe571d4f-aac8-4ce3-9865-78890a5347e9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fe571d4f-aac8-4ce3-9865-78890a5347e9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

file_path = 'total-phone-devices-by-company-v2.csv'
df = pd.read_csv('total-phone-devices-by-company-v2.csv')

df.head()
# Out:
#    Company  Total_Devices
# 0     ACER            100
# 1  ALLVIEW            157
# 2     AMOI             47
# 3   ARCHOS             43
# 4     AT&T              4
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Total_Devices'].plot(kind='hist', bins=20, title='Total_Devices')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Company').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        117 non-null    object
#  1   Total_Devices  117 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.0+ KB
# None

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 112    False
# 113    False
# 114    False
# 115    False
# 116    False
# Length: 117, dtype: bool

# %%
shortened = df.tail(10)
print(shortened)
# Out:
#       Company  Total_Devices
# 107   TEL.ME.              7
# 108   THURAYA              1
# 109   ULEFONE             57
# 110     VERTU             17
# 111      VIVO            293
# 112  VODAFONE             87
# 113       WND              5
# 114    XIAOMI            278
# 115      YEZZ            103
# 116        YU             13

# %%
import matplotlib.pyplot

# %% [markdown]
# THREE QUESTIONS:
# Whhich phone brand is the best
# what is the overall distribution of total devices
# Which companies are most frequently represented in the dataset?

# %%
g = np.array([1, 2, 3])
brands = ["acer = 1", "allview = 2", "Amoi = 3"]
plt.pie(g,labels = brands)
plt.show()

# %%
categories = ['ACER', 'ALLVIEW', 'AMOI', 'ARCHOS', 'AT&T']
total_devices = [100, 157, 47, 43, 4]

plt.figure(figsize=(12, 6))
plt.bar(categories, total_devices)
plt.title("Bar Chart Example")
plt.xlabel("Brands")
plt.ylabel("total devices")
plt.show()

# %%
from matplotlib import pyplot as plt
_df_0['Total_Devices'].plot(kind='hist', bins=20, title='Total_Devices')
plt.gca().spines[['top', 'right',]].set_visible(False)
